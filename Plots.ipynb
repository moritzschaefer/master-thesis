# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
0.625/0.545
# Out:
# 1.146788990825688

# %%
sns.barplot(x=[0, 1], y=[0.505, 0.545])
plt.xticks([0,1], ['Doench 2014', 'Azimuth 2016 (Doench)'])
plt.ylim(0.4, 0.58)
plt.ylabel('Spearman correlation')
plt.title('Performance comparison of guide efficacy models')
plt.text(0.875, 0.525, str('+ 7.9%'), color='blue', fontdict={'size': 12})
plt.savefig('model_comparison1.png', dpi=130)

# %%
sns.barplot(x=[0, 1, 2], y=[0.505, 0.545, 0.625])
plt.xticks([0,1,2], ['Doench 2014', 'Azimuth 2016 (Doench)', 'PAVOOC 2018'])
plt.ylim(0.4, 0.64)
plt.ylabel('Spearman correlation')
plt.title('Performance comparison of guide efficacy models')
plt.text(1.77, 0.59, str('+ 14.7%'), color='blue', fontdict={'size': 12})
plt.savefig('model_comparison2.png', dpi=130)
